# %%
import ast
import numpy as np
import time
import sys
import pandas as pd
import subprocess
import pickle
import math
from collections import Counter

# %%
# Calculate list npm1 kmers from sequence
with open('data/NM_001355006.1.exons.fa') as f:
    seq = ''
    for line in f.readlines():
        if line[0] != '>':
            seq += line.strip()
print(len(seq))
npm1_kmers = []
k = 31
kmer_count = Counter()
for i in range(len(seq)-30):
    kmer_count[seq[i:i+k]] += 1
npm1_kmers = list(kmer_count.keys())
# Out:
# 1339

# %%
len(npm1_kmers)
# Out:
# 1309

# %%
# Read files for list of all patient ids
with open("data/patient_list.txt") as f:
    patient_list = f.read().split()

# %%
def kmc_to_str(kmc):
    # Converts kmer count 2d array into string of just the kmers, separated by spaces
    return str(kmc).replace(',', "").replace("'", '')[1:-1]
kms_str = kmc_to_str(npm1_kmers)

# %%
start_i = 0
num_kmers = len(npm1_kmers)
kmer_table = pd.DataFrame(np.zeros((len(patient_list), num_kmers+1)))

# %%
# Loading saved kmer_table
with open('data/temp_kmer_table.py', 'rb') as f:
    kmer_table = pickle.load(f)
start_i = int(kmer_table.iloc[:,-1].idxmax())
if int(kmer_table.iloc[-1,-1]) == -1:
    start_i = kmer_table.shape[0]

# %%
# Query all patients for specific kmers, but store in DataFrame
def query_np(patients, kms):
    global kmer_table
    global start_i
    global num_kmers
    i = start_i
    if i != 0:
        print(f"Restarting at patient #{i+1}")
    BUFFER_SIZE = 5
    buffer = np.zeros((BUFFER_SIZE, num_kmers+1))
    for p in patients[start_i:]:
        jf = f"/u/leucegene/data/sample/{p}/transcriptome/jellyfish/2.2.3/kmers.k31.CL2.jf"
        n = 0
        output = ""
        for n in range(math.ceil(num_kmers/100)):
            kms_subset = kmc_to_str(npm1_kmers[n*100:(n+1)*100])
            cmd = f"jellyfish query {jf} {kms_subset}"
            output = output + subprocess.getoutput(cmd) + '\n'
        j = 0
        for line in output[:-1].splitlines():
            km, cnt = line.split()
            buffer[i%BUFFER_SIZE,j] = int(cnt)
            j += 1
        buffer[i%BUFFER_SIZE,-1] = -1 # Indicates that this line has been queried
        i += 1
        timestamp = time.strftime("%H:%M:%S", time.localtime())
        print(f"\r{timestamp}: Queried patient #{i} ({p})...", end='')
        if i % BUFFER_SIZE == 0 or i == kmer_table.shape[0]:
            # Dump buffer
            buffer = np.delete(buffer, np.where(buffer[:,-1] == 0), axis=0)
            kmer_table.iloc[i-buffer.shape[0]:i] = buffer
            buffer = np.zeros((BUFFER_SIZE, num_kmers+1))
            print(f"Dumped buffer after patient #{i} ({p})!")
            start_i = i
        if i % (BUFFER_SIZE*2) == 0 or i == kmer_table.shape[0]:
            # Backup to disk
            with open('data/temp_kmer_table.py', 'wb') as f:
                pickle.dump(kmer_table, f)
            print(f"Backed up to disk after patient #{i} ({p})...")

# %%
# For each patient, extract kmer counts and put it in a DataFrame
query_np(patient_list, kms_str)
if int(kmer_table.iloc[-1,-1]) == -1:
    print("Done querying!")
# Out:
# 01:50:38: Queried patient #5 (02H017)...Dumped buffer after patient #5 (02H017)!
# 01:51:32: Queried patient #10 (02H043)...Dumped buffer after patient #10 (02H043)!
# Backed up to disk after patient #10 (02H043)...
# 01:52:31: Queried patient #15 (02H080)...Dumped buffer after patient #15 (02H080)!
# 01:53:30: Queried patient #20 (03H028)...Dumped buffer after patient #20 (03H028)!
# Backed up to disk after patient #20 (03H028)...
# 01:54:32: Queried patient #25 (03H049)...Dumped buffer after patient #25 (03H049)!
# 01:55:30: Queried patient #30 (03H070)...Dumped buffer after patient #30 (03H070)!
# Backed up to disk after patient #30 (03H070)...
# 01:56:30: Queried patient #35 (03H094)...Dumped buffer after patient #35 (03H094)!
# 01:57:34: Queried patient #40 (03H116)...Dumped buffer after patient #40 (03H116)!
# Backed up to disk after patient #40 (03H116)...
# 01:58:34: Queried patient #45 (04H017)...Dumped buffer after patient #45 (04H017)!
# 01:59:34: Queried patient #50 (04H039)...Dumped buffer after patient #50 (04H039)!
# Backed up to disk after patient #50 (04H039)...
# 02:00:36: Queried patient #55 (04H055)...Dumped buffer after patient #55 (04H055)!
# 02:01:39: Queried patient #60 (04H080)...Dumped buffer after patient #60 (04H080)!
# Backed up to disk after patient #60 (04H080)...
# 02:02:44: Queried patient #65 (04H100)...Dumped buffer after patient #65 (04H100)!
# 02:03:49: Queried patient #70 (04H111)...Dumped buffer after patient #70 (04H111)!
# Backed up to disk after patient #70 (04H111)...
# 02:04:52: Queried patient #75 (04H120)...Dumped buffer after patient #75 (04H120)!
# 02:05:53: Queried patient #80 (04H133)...Dumped buffer after patient #80 (04H133)!
# Backed up to disk after patient #80 (04H133)...
# 02:07:00: Queried patient #85 (05H004)...Dumped buffer after patient #85 (05H004)!
# 02:08:07: Queried patient #90 (05H030)...Dumped buffer after patient #90 (05H030)!
# Backed up to disk after patient #90 (05H030)...
# 02:09:12: Queried patient #95 (05H042)...Dumped buffer after patient #95 (05H042)!
# 02:10:19: Queried patient #100 (05H065)...Dumped buffer after patient #100 (05H065)!
# Backed up to disk after patient #100 (05H065)...
# 02:11:25: Queried patient #105 (05H090)...Dumped buffer after patient #105 (05H090)!
# 02:12:24: Queried patient #110 (05H108)...Dumped buffer after patient #110 (05H108)!
# Backed up to disk after patient #110 (05H108)...
# 02:13:29: Queried patient #115 (05H128)...Dumped buffer after patient #115 (05H128)!
# 02:14:38: Queried patient #120 (05H155)...Dumped buffer after patient #120 (05H155)!
# Backed up to disk after patient #120 (05H155)...
# 02:15:54: Queried patient #125 (05H180)...Dumped buffer after patient #125 (05H180)!
# 02:17:00: Queried patient #130 (05H193)...Dumped buffer after patient #130 (05H193)!
# Backed up to disk after patient #130 (05H193)...
# 02:18:05: Queried patient #135 (06H014)...Dumped buffer after patient #135 (06H014)!
# 02:19:07: Queried patient #140 (06H026)...Dumped buffer after patient #140 (06H026)!
# Backed up to disk after patient #140 (06H026)...
# 02:20:12: Queried patient #145 (06H038)...Dumped buffer after patient #145 (06H038)!
# 02:21:30: Queried patient #150 (06H061)...Dumped buffer after patient #150 (06H061)!
# Backed up to disk after patient #150 (06H061)...
# 02:22:38: Queried patient #155 (06H075)...Dumped buffer after patient #155 (06H075)!
# 02:23:43: Queried patient #160 (06H099)...Dumped buffer after patient #160 (06H099)!
# Backed up to disk after patient #160 (06H099)...
# 02:24:48: Queried patient #165 (06H117)...Dumped buffer after patient #165 (06H117)!
# 02:25:55: Queried patient #170 (06H144)...Dumped buffer after patient #170 (06H144)!
# Backed up to disk after patient #170 (06H144)...
# 02:27:03: Queried patient #175 (07H005)...Dumped buffer after patient #175 (07H005)!
# 02:28:08: Queried patient #180 (07H024)...Dumped buffer after patient #180 (07H024)!
# Backed up to disk after patient #180 (07H024)...
# 02:29:09: Queried patient #185 (07H043)...Dumped buffer after patient #185 (07H043)!
# 02:30:14: Queried patient #190 (07H060)...Dumped buffer after patient #190 (07H060)!
# Backed up to disk after patient #190 (07H060)...
# 02:31:20: Queried patient #195 (07H073)...Dumped buffer after patient #195 (07H073)!
# 02:32:25: Queried patient #200 (07H095)...Dumped buffer after patient #200 (07H095)!
# Backed up to disk after patient #200 (07H095)...
# 02:33:26: Queried patient #205 (07H112)...Dumped buffer after patient #205 (07H112)!
# 02:34:25: Queried patient #210 (07H133)...Dumped buffer after patient #210 (07H133)!
# Backed up to disk after patient #210 (07H133)...
# 02:35:31: Queried patient #215 (07H142)...Dumped buffer after patient #215 (07H142)!
# 02:36:34: Queried patient #220 (07H155)...Dumped buffer after patient #220 (07H155)!
# Backed up to disk after patient #220 (07H155)...
# 02:37:36: Queried patient #225 (08H011)...Dumped buffer after patient #225 (08H011)!
# 02:38:38: Queried patient #230 (08H033)...Dumped buffer after patient #230 (08H033)!
# Backed up to disk after patient #230 (08H033)...
# 02:39:40: Queried patient #235 (08H049)...Dumped buffer after patient #235 (08H049)!
# 02:40:41: Queried patient #240 (08H056)...Dumped buffer after patient #240 (08H056)!
# Backed up to disk after patient #240 (08H056)...
# 02:41:48: Queried patient #245 (08H072)...Dumped buffer after patient #245 (08H072)!
# 02:42:57: Queried patient #250 (08H087)...Dumped buffer after patient #250 (08H087)!
# Backed up to disk after patient #250 (08H087)...
# 02:44:03: Queried patient #255 (08H104)...Dumped buffer after patient #255 (08H104)!
# 02:45:10: Queried patient #260 (08H118)...Dumped buffer after patient #260 (08H118)!
# Backed up to disk after patient #260 (08H118)...
# 02:46:15: Queried patient #265 (09H002)...Dumped buffer after patient #265 (09H002)!
# 02:47:18: Queried patient #270 (09H015)...Dumped buffer after patient #270 (09H015)!
# Backed up to disk after patient #270 (09H015)...
# 02:48:21: Queried patient #275 (09H026)...Dumped buffer after patient #275 (09H026)!
# 02:49:27: Queried patient #280 (09H040)...Dumped buffer after patient #280 (09H040)!
# Backed up to disk after patient #280 (09H040)...
# 02:50:31: Queried patient #285 (09H048)...Dumped buffer after patient #285 (09H048)!
# 02:51:33: Queried patient #290 (09H060)...Dumped buffer after patient #290 (09H060)!
# Backed up to disk after patient #290 (09H060)...
# 02:52:36: Queried patient #295 (09H078)...Dumped buffer after patient #295 (09H078)!
# 02:53:39: Queried patient #300 (09H088)...Dumped buffer after patient #300 (09H088)!
# Backed up to disk after patient #300 (09H088)...
# 02:54:42: Queried patient #305 (09H098)...Dumped buffer after patient #305 (09H098)!
# 02:55:46: Queried patient #310 (09H115)...Dumped buffer after patient #310 (09H115)!
# Backed up to disk after patient #310 (09H115)...
# 02:56:56: Queried patient #315 (10H005)...Dumped buffer after patient #315 (10H005)!
# 02:57:58: Queried patient #320 (10H017)...Dumped buffer after patient #320 (10H017)!
# Backed up to disk after patient #320 (10H017)...
# 02:58:58: Queried patient #325 (10H030)...Dumped buffer after patient #325 (10H030)!
# 03:00:16: Queried patient #330 (10H044)...Dumped buffer after patient #330 (10H044)!
# Backed up to disk after patient #330 (10H044)...
# 03:01:20: Queried patient #335 (10H052)...Dumped buffer after patient #335 (10H052)!
# 03:02:18: Queried patient #340 (10H059)...Dumped buffer after patient #340 (10H059)!
# Backed up to disk after patient #340 (10H059)...
# 03:03:22: Queried patient #345 (10H072)...Dumped buffer after patient #345 (10H072)!
# 03:04:28: Queried patient #350 (10H092)...Dumped buffer after patient #350 (10H092)!
# Backed up to disk after patient #350 (10H092)...
# 03:05:31: Queried patient #355 (10H109)...Dumped buffer after patient #355 (10H109)!
# 03:06:39: Queried patient #360 (10H119)...Dumped buffer after patient #360 (10H119)!
# Backed up to disk after patient #360 (10H119)...
# 03:07:49: Queried patient #365 (10H136)...Dumped buffer after patient #365 (10H136)!
# 03:08:53: Queried patient #370 (10H173)...Dumped buffer after patient #370 (10H173)!
# Backed up to disk after patient #370 (10H173)...
# 03:10:04: Queried patient #375 (11H008)...Dumped buffer after patient #375 (11H008)!
# 03:11:14: Queried patient #380 (11H017)...Dumped buffer after patient #380 (11H017)!
# Backed up to disk after patient #380 (11H017)...
# 03:12:21: Queried patient #385 (11H035)...Dumped buffer after patient #385 (11H035)!
# 03:13:29: Queried patient #390 (11H067)...Dumped buffer after patient #390 (11H067)!
# Backed up to disk after patient #390 (11H067)...
# 03:14:35: Queried patient #395 (11H097)...Dumped buffer after patient #395 (11H097)!
# 03:15:38: Queried patient #400 (11H127)...Dumped buffer after patient #400 (11H127)!
# Backed up to disk after patient #400 (11H127)...
# 03:16:42: Queried patient #405 (11H140)...Dumped buffer after patient #405 (11H140)!
# 03:17:48: Queried patient #410 (11H160)...Dumped buffer after patient #410 (11H160)!
# Backed up to disk after patient #410 (11H160)...
# 03:19:00: Queried patient #415 (11H182)...Dumped buffer after patient #415 (11H182)!
# 03:20:10: Queried patient #420 (11H194)...Dumped buffer after patient #420 (11H194)!
# Backed up to disk after patient #420 (11H194)...
# 03:21:28: Queried patient #425 (11H230)...Dumped buffer after patient #425 (11H230)!
# 03:22:34: Queried patient #430 (12H007)...Dumped buffer after patient #430 (12H007)!
# Backed up to disk after patient #430 (12H007)...
# 03:23:39: Queried patient #435 (12H030)...Dumped buffer after patient #435 (12H030)!
# 03:24:52: Queried patient #440 (12H045)...Dumped buffer after patient #440 (12H045)!
# Backed up to disk after patient #440 (12H045)...
# 03:26:22: Queried patient #445 (12H058)...Dumped buffer after patient #445 (12H058)!
# 03:27:53: Queried patient #450 (12H091)...Dumped buffer after patient #450 (12H091)!
# Backed up to disk after patient #450 (12H091)...
# 03:29:18: Queried patient #455 (12H117)...Dumped buffer after patient #455 (12H117)!
# 03:30:48: Queried patient #460 (12H139)...Dumped buffer after patient #460 (12H139)!
# Backed up to disk after patient #460 (12H139)...
# 03:32:16: Queried patient #465 (12H159)...Dumped buffer after patient #465 (12H159)!
# 03:33:39: Queried patient #470 (12H172)...Dumped buffer after patient #470 (12H172)!
# Backed up to disk after patient #470 (12H172)...
# 03:35:02: Queried patient #475 (12H183)...Dumped buffer after patient #475 (12H183)!
# 03:36:26: Queried patient #480 (13H018)...Dumped buffer after patient #480 (13H018)!
# Backed up to disk after patient #480 (13H018)...
# 03:37:47: Queried patient #485 (13H053)...Dumped buffer after patient #485 (13H053)!
# 03:39:20: Queried patient #490 (13H065)...Dumped buffer after patient #490 (13H065)!
# Backed up to disk after patient #490 (13H065)...
# 03:40:45: Queried patient #495 (13H080)...Dumped buffer after patient #495 (13H080)!
# 03:42:16: Queried patient #500 (13H104)...Dumped buffer after patient #500 (13H104)!
# Backed up to disk after patient #500 (13H104)...
# 03:43:44: Queried patient #505 (13H120)...Dumped buffer after patient #505 (13H120)!
# 03:45:12: Queried patient #510 (13H141)...Dumped buffer after patient #510 (13H141)!
# Backed up to disk after patient #510 (13H141)...
# 03:46:44: Queried patient #515 (13H166)...Dumped buffer after patient #515 (13H166)!
# 03:48:19: Queried patient #520 (13H182)...Dumped buffer after patient #520 (13H182)!
# Backed up to disk after patient #520 (13H182)...
# 03:49:52: Queried patient #525 (14H007)...Dumped buffer after patient #525 (14H007)!
# 03:51:24: Queried patient #530 (14H019)...Dumped buffer after patient #530 (14H019)!
# Backed up to disk after patient #530 (14H019)...
# 03:53:03: Queried patient #535 (14H027)...Dumped buffer after patient #535 (14H027)!
# 03:54:41: Queried patient #540 (14H051)...Dumped buffer after patient #540 (14H051)!
# Backed up to disk after patient #540 (14H051)...
# 03:56:15: Queried patient #545 (14H093)...Dumped buffer after patient #545 (14H093)!
# 03:57:54: Queried patient #550 (14H109)...Dumped buffer after patient #550 (14H109)!
# Backed up to disk after patient #550 (14H109)...
# 03:59:32: Queried patient #555 (14H133)...Dumped buffer after patient #555 (14H133)!
# 04:01:16: Queried patient #560 (14H156)...Dumped buffer after patient #560 (14H156)!
# Backed up to disk after patient #560 (14H156)...
# 04:02:56: Queried patient #565 (15H003)...Dumped buffer after patient #565 (15H003)!
# 04:04:32: Queried patient #570 (15H036)...Dumped buffer after patient #570 (15H036)!
# Backed up to disk after patient #570 (15H036)...
# 04:06:10: Queried patient #575 (15H049)...Dumped buffer after patient #575 (15H049)!
# 04:07:46: Queried patient #580 (15H063)...Dumped buffer after patient #580 (15H063)!
# Backed up to disk after patient #580 (15H063)...
# 04:09:10: Queried patient #585 (15H080)...Dumped buffer after patient #585 (15H080)!
# 04:10:39: Queried patient #590 (15H103)...Dumped buffer after patient #590 (15H103)!
# Backed up to disk after patient #590 (15H103)...
# 04:12:15: Queried patient #595 (15H135)...Dumped buffer after patient #595 (15H135)!
# 04:14:01: Queried patient #600 (16H008)...Dumped buffer after patient #600 (16H008)!
# Backed up to disk after patient #600 (16H008)...
# 04:15:37: Queried patient #605 (16H027)...Dumped buffer after patient #605 (16H027)!
# 04:17:01: Queried patient #610 (16H064)...Dumped buffer after patient #610 (16H064)!
# Backed up to disk after patient #610 (16H064)...
# 04:18:29: Queried patient #615 (16H097)...Dumped buffer after patient #615 (16H097)!
# 04:19:47: Queried patient #620 (16H106)...Dumped buffer after patient #620 (16H106)!
# Backed up to disk after patient #620 (16H106)...
# 04:21:06: Queried patient #625 (16H119)...Dumped buffer after patient #625 (16H119)!
# 04:22:31: Queried patient #630 (16H144)...Dumped buffer after patient #630 (16H144)!
# Backed up to disk after patient #630 (16H144)...
# 04:23:53: Queried patient #635 (17H027)...Dumped buffer after patient #635 (17H027)!
# 04:25:15: Queried patient #640 (17H045)...Dumped buffer after patient #640 (17H045)!
# Backed up to disk after patient #640 (17H045)...
# 04:26:35: Queried patient #645 (17H075)...Dumped buffer after patient #645 (17H075)!
# 04:27:55: Queried patient #650 (17H154)...Dumped buffer after patient #650 (17H154)!
# Backed up to disk after patient #650 (17H154)...
# 04:29:23: Queried patient #655 (17H209)...Dumped buffer after patient #655 (17H209)!
# 04:31:03: Queried patient #660 (18H030)...Dumped buffer after patient #660 (18H030)!
# Backed up to disk after patient #660 (18H030)...
# 04:32:33: Queried patient #665 (18H058)...Dumped buffer after patient #665 (18H058)!
# 04:33:59: Queried patient #670 (18H093)...Dumped buffer after patient #670 (18H093)!
# Backed up to disk after patient #670 (18H093)...
# 04:35:43: Queried patient #675 (18H131)...Dumped buffer after patient #675 (18H131)!
# 04:37:32: Queried patient #680 (18H151)...Dumped buffer after patient #680 (18H151)!
# Backed up to disk after patient #680 (18H151)...
# 04:39:24: Queried patient #685 (18H182)...Dumped buffer after patient #685 (18H182)!
# 04:40:54: Queried patient #690 (18H208)...Dumped buffer after patient #690 (18H208)!
# Backed up to disk after patient #690 (18H208)...
# 04:41:15: Queried patient #691 (19H045)...Dumped buffer after patient #691 (19H045)!
# Backed up to disk after patient #691 (19H045)...
# Done querying!

# %%
# Processing & export finished data
kmer_table.columns = [f"km_{i}" for i in range(num_kmers)] + ["queried"]
export = kmer_table.drop("queried", axis=1)
with open('data/km_table_npm1.py', 'wb') as f:
    pickle.dump(export, f)

# %%
kmer_table.shape
# Out:
# (691, 1310)
